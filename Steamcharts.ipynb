# %%
# setup dependencies
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
import pymongo

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [/Users/nicolevandriss/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache

# %%
url = "https://steamcharts.com/"
browser.visit(url)

# %%
html = browser.html
soup = bs(html,'html.parser')

# %%
top5_table = soup.find('table', id="top-games")
rows = top5_table.findAll('tr')
print (rows)
# Out:
# [<tr>
# <th></th>
# <th class="left">Name</th>
# <th>Current Players</th>
# <th class="period-col" id="topgames-chart-head">Last 30 Days</th>
# <th class="period-col">Peak Players</th>
# <th class="period-col">Hours Played</th>
# </tr>, <tr class="odd">
# <td>1.</td>
# <td class="game-name left">
# <a href="/app/730">
# 						Counter-Strike: Global Offensive
# 					</a>
# </td>
# <td class="num">397,402</td>
# <td class="chart period-col" id="spark_730" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="39" width="4" x="0" y="1"></rect><rect class="hours-bar" height="33" width="4" x="5" y="7"></rect><rect class="hours-bar" height="34" width="4" x="10" y="6"></rect><rect class="hours-bar" height="31" width="4" x="15" y="9"></rect><rect class="hours-bar" height="31" width="4" x="20" y="9"></rect><rect class="hours-bar" height="34" width="4" x="25" y="6"></rect><rect class="hours-bar" height="40" width="4" x="30" y="0"></rect><rect class="hours-bar" height="38" width="4" x="35" y="2"></rect><rect class="hours-bar" height="32" width="4" x="40" y="8"></rect><rect class="hours-bar" height="33" width="4" x="45" y="7"></rect><rect class="hours-bar" height="33" width="4" x="50" y="7"></rect><rect class="hours-bar" height="33" width="4" x="55" y="7"></rect><rect class="hours-bar" height="35" width="4" x="60" y="5"></rect><rect class="hours-bar" height="36" width="4" x="65" y="4"></rect><rect class="hours-bar" height="36" width="4" x="70" y="4"></rect><rect class="hours-bar" height="34" width="4" x="75" y="6"></rect><rect class="hours-bar" height="35" width="4" x="80" y="5"></rect><rect class="hours-bar" height="37" width="4" x="85" y="3"></rect><rect class="hours-bar" height="36" width="4" x="90" y="4"></rect><rect class="hours-bar" height="33" width="4" x="95" y="7"></rect><rect class="hours-bar" height="36" width="4" x="100" y="4"></rect><rect class="hours-bar" height="39" width="4" x="105" y="1"></rect><rect class="hours-bar" height="37" width="4" x="110" y="3"></rect><rect class="hours-bar" height="36" width="4" x="115" y="4"></rect><rect class="hours-bar" height="37" width="4" x="120" y="3"></rect><rect class="hours-bar" height="36" width="4" x="125" y="4"></rect><rect class="hours-bar" height="37" width="4" x="130" y="3"></rect><rect class="hours-bar" height="40" width="4" x="135" y="0"></rect><rect class="hours-bar" height="40" width="4" x="140" y="0"></rect><rect class="hours-bar" height="35" width="4" x="145" y="5"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">895,365</td>
# <td class="num period-col player-hours">394,556,094</td>
# </tr>, <tr>
# <td>2.</td>
# <td class="game-name left">
# <a href="/app/570">
# 						Dota 2
# 					</a>
# </td>
# <td class="num">344,758</td>
# <td class="chart period-col" id="spark_570" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="32" width="4" x="0" y="8"></rect><rect class="hours-bar" height="27" width="4" x="5" y="13"></rect><rect class="hours-bar" height="28" width="4" x="10" y="12"></rect><rect class="hours-bar" height="32" width="4" x="15" y="8"></rect><rect class="hours-bar" height="32" width="4" x="20" y="8"></rect><rect class="hours-bar" height="32" width="4" x="25" y="8"></rect><rect class="hours-bar" height="36" width="4" x="30" y="4"></rect><rect class="hours-bar" height="36" width="4" x="35" y="4"></rect><rect class="hours-bar" height="31" width="4" x="40" y="9"></rect><rect class="hours-bar" height="31" width="4" x="45" y="9"></rect><rect class="hours-bar" height="32" width="4" x="50" y="8"></rect><rect class="hours-bar" height="32" width="4" x="55" y="8"></rect><rect class="hours-bar" height="33" width="4" x="60" y="7"></rect><rect class="hours-bar" height="36" width="4" x="65" y="4"></rect><rect class="hours-bar" height="37" width="4" x="70" y="3"></rect><rect class="hours-bar" height="34" width="4" x="75" y="6"></rect><rect class="hours-bar" height="34" width="4" x="80" y="6"></rect><rect class="hours-bar" height="34" width="4" x="85" y="6"></rect><rect class="hours-bar" height="34" width="4" x="90" y="6"></rect><rect class="hours-bar" height="31" width="4" x="95" y="9"></rect><rect class="hours-bar" height="34" width="4" x="100" y="6"></rect><rect class="hours-bar" height="38" width="4" x="105" y="2"></rect><rect class="hours-bar" height="36" width="4" x="110" y="4"></rect><rect class="hours-bar" height="34" width="4" x="115" y="6"></rect><rect class="hours-bar" height="33" width="4" x="120" y="7"></rect><rect class="hours-bar" height="33" width="4" x="125" y="7"></rect><rect class="hours-bar" height="34" width="4" x="130" y="6"></rect><rect class="hours-bar" height="37" width="4" x="135" y="3"></rect><rect class="hours-bar" height="37" width="4" x="140" y="3"></rect><rect class="hours-bar" height="31" width="4" x="145" y="9"></rect><rect class="hours-bar ongoing" height="2" width="4" x="150" y="38"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">760,295</td>
# <td class="num period-col player-hours">346,344,640</td>
# </tr>, <tr class="odd">
# <td>3.</td>
# <td class="game-name left">
# <a href="/app/252490">
# 						Rust
# 					</a>
# </td>
# <td class="num">102,311</td>
# <td class="chart period-col" id="spark_252490" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="28" width="4" x="0" y="12"></rect><rect class="hours-bar" height="21" width="4" x="5" y="19"></rect><rect class="hours-bar" height="21" width="4" x="10" y="19"></rect><rect class="hours-bar" height="19" width="4" x="15" y="21"></rect><rect class="hours-bar" height="21" width="4" x="20" y="19"></rect><rect class="hours-bar" height="25" width="4" x="25" y="15"></rect><rect class="hours-bar" height="29" width="4" x="30" y="11"></rect><rect class="hours-bar" height="28" width="4" x="35" y="12"></rect><rect class="hours-bar" height="24" width="4" x="40" y="16"></rect><rect class="hours-bar" height="25" width="4" x="45" y="15"></rect><rect class="hours-bar" height="24" width="4" x="50" y="16"></rect><rect class="hours-bar" height="25" width="4" x="55" y="15"></rect><rect class="hours-bar" height="26" width="4" x="60" y="14"></rect><rect class="hours-bar" height="25" width="4" x="65" y="15"></rect><rect class="hours-bar" height="27" width="4" x="70" y="13"></rect><rect class="hours-bar" height="28" width="4" x="75" y="12"></rect><rect class="hours-bar" height="29" width="4" x="80" y="11"></rect><rect class="hours-bar" height="28" width="4" x="85" y="12"></rect><rect class="hours-bar" height="29" width="4" x="90" y="11"></rect><rect class="hours-bar" height="28" width="4" x="95" y="12"></rect><rect class="hours-bar" height="29" width="4" x="100" y="11"></rect><rect class="hours-bar" height="31" width="4" x="105" y="9"></rect><rect class="hours-bar" height="28" width="4" x="110" y="12"></rect><rect class="hours-bar" height="27" width="4" x="115" y="13"></rect><rect class="hours-bar" height="24" width="4" x="120" y="16"></rect><rect class="hours-bar" height="25" width="4" x="125" y="15"></rect><rect class="hours-bar" height="38" width="4" x="130" y="2"></rect><rect class="hours-bar" height="40" width="4" x="135" y="0"></rect><rect class="hours-bar" height="39" width="4" x="140" y="1"></rect><rect class="hours-bar" height="30" width="4" x="145" y="10"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">154,747</td>
# <td class="num period-col player-hours">58,578,091</td>
# </tr>, <tr>
# <td>4.</td>
# <td class="game-name left">
# <a href="/app/1172470">
# 						Apex Legends
# 					</a>
# </td>
# <td class="num">84,119</td>
# <td class="chart period-col" id="spark_1172470" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="35" width="4" x="0" y="5"></rect><rect class="hours-bar" height="27" width="4" x="5" y="13"></rect><rect class="hours-bar" height="27" width="4" x="10" y="13"></rect><rect class="hours-bar" height="26" width="4" x="15" y="14"></rect><rect class="hours-bar" height="27" width="4" x="20" y="13"></rect><rect class="hours-bar" height="28" width="4" x="25" y="12"></rect><rect class="hours-bar" height="32" width="4" x="30" y="8"></rect><rect class="hours-bar" height="31" width="4" x="35" y="9"></rect><rect class="hours-bar" height="26" width="4" x="40" y="14"></rect><rect class="hours-bar" height="27" width="4" x="45" y="13"></rect><rect class="hours-bar" height="30" width="4" x="50" y="10"></rect><rect class="hours-bar" height="30" width="4" x="55" y="10"></rect><rect class="hours-bar" height="30" width="4" x="60" y="10"></rect><rect class="hours-bar" height="32" width="4" x="65" y="8"></rect><rect class="hours-bar" height="33" width="4" x="70" y="7"></rect><rect class="hours-bar" height="30" width="4" x="75" y="10"></rect><rect class="hours-bar" height="31" width="4" x="80" y="9"></rect><rect class="hours-bar" height="32" width="4" x="85" y="8"></rect><rect class="hours-bar" height="32" width="4" x="90" y="8"></rect><rect class="hours-bar" height="31" width="4" x="95" y="9"></rect><rect class="hours-bar" height="33" width="4" x="100" y="7"></rect><rect class="hours-bar" height="35" width="4" x="105" y="5"></rect><rect class="hours-bar" height="33" width="4" x="110" y="7"></rect><rect class="hours-bar" height="32" width="4" x="115" y="8"></rect><rect class="hours-bar" height="31" width="4" x="120" y="9"></rect><rect class="hours-bar" height="31" width="4" x="125" y="9"></rect><rect class="hours-bar" height="33" width="4" x="130" y="7"></rect><rect class="hours-bar" height="37" width="4" x="135" y="3"></rect><rect class="hours-bar" height="38" width="4" x="140" y="2"></rect><rect class="hours-bar" height="32" width="4" x="145" y="8"></rect><rect class="hours-bar ongoing" height="2" width="4" x="150" y="38"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">238,911</td>
# <td class="num period-col player-hours">92,000,952</td>
# </tr>, <tr class="odd">
# <td>5.</td>
# <td class="game-name left">
# <a href="/app/440">
# 						Team Fortress 2
# 					</a>
# </td>
# <td class="num">83,248</td>
# <td class="chart period-col" id="spark_440" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="24" width="4" x="0" y="16"></rect><rect class="hours-bar" height="22" width="4" x="5" y="18"></rect><rect class="hours-bar" height="21" width="4" x="10" y="19"></rect><rect class="hours-bar" height="20" width="4" x="15" y="20"></rect><rect class="hours-bar" height="22" width="4" x="20" y="18"></rect><rect class="hours-bar" height="25" width="4" x="25" y="15"></rect><rect class="hours-bar" height="25" width="4" x="30" y="15"></rect><rect class="hours-bar" height="25" width="4" x="35" y="15"></rect><rect class="hours-bar" height="29" width="4" x="40" y="11"></rect><rect class="hours-bar" height="35" width="4" x="45" y="5"></rect><rect class="hours-bar" height="25" width="4" x="50" y="15"></rect><rect class="hours-bar" height="32" width="4" x="55" y="8"></rect><rect class="hours-bar" height="38" width="4" x="60" y="2"></rect><rect class="hours-bar" height="38" width="4" x="65" y="2"></rect><rect class="hours-bar" height="39" width="4" x="70" y="1"></rect><rect class="hours-bar" height="38" width="4" x="75" y="2"></rect><rect class="hours-bar" height="38" width="4" x="80" y="2"></rect><rect class="hours-bar" height="36" width="4" x="85" y="4"></rect><rect class="hours-bar" height="35" width="4" x="90" y="5"></rect><rect class="hours-bar" height="40" width="4" x="95" y="0"></rect><rect class="hours-bar" height="40" width="4" x="100" y="0"></rect><rect class="hours-bar" height="40" width="4" x="105" y="0"></rect><rect class="hours-bar" height="40" width="4" x="110" y="0"></rect><rect class="hours-bar" height="39" width="4" x="115" y="1"></rect><rect class="hours-bar" height="35" width="4" x="120" y="5"></rect><rect class="hours-bar" height="31" width="4" x="125" y="9"></rect><rect class="hours-bar" height="28" width="4" x="130" y="12"></rect><rect class="hours-bar" height="26" width="4" x="135" y="14"></rect><rect class="hours-bar" height="27" width="4" x="140" y="13"></rect><rect class="hours-bar" height="26" width="4" x="145" y="14"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">129,305</td>
# <td class="num period-col player-hours">69,420,317</td>
# </tr>, <tr>
# <td>6.</td>
# <td class="game-name left">
# <a href="/app/1063730">
# 						New World
# 					</a>
# </td>
# <td class="num">74,492</td>
# <td class="chart period-col" id="spark_1063730" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="38" width="4" x="0" y="2"></rect><rect class="hours-bar" height="32" width="4" x="5" y="8"></rect><rect class="hours-bar" height="31" width="4" x="10" y="9"></rect><rect class="hours-bar" height="30" width="4" x="15" y="10"></rect><rect class="hours-bar" height="29" width="4" x="20" y="11"></rect><rect class="hours-bar" height="35" width="4" x="25" y="5"></rect><rect class="hours-bar" height="37" width="4" x="30" y="3"></rect><rect class="hours-bar" height="39" width="4" x="35" y="1"></rect><rect class="hours-bar" height="33" width="4" x="40" y="7"></rect><rect class="hours-bar" height="35" width="4" x="45" y="5"></rect><rect class="hours-bar" height="32" width="4" x="50" y="8"></rect><rect class="hours-bar" height="34" width="4" x="55" y="6"></rect><rect class="hours-bar" height="32" width="4" x="60" y="8"></rect><rect class="hours-bar" height="31" width="4" x="65" y="9"></rect><rect class="hours-bar" height="35" width="4" x="70" y="5"></rect><rect class="hours-bar" height="36" width="4" x="75" y="4"></rect><rect class="hours-bar" height="36" width="4" x="80" y="4"></rect><rect class="hours-bar" height="35" width="4" x="85" y="5"></rect><rect class="hours-bar" height="35" width="4" x="90" y="5"></rect><rect class="hours-bar" height="32" width="4" x="95" y="8"></rect><rect class="hours-bar" height="33" width="4" x="100" y="7"></rect><rect class="hours-bar" height="37" width="4" x="105" y="3"></rect><rect class="hours-bar" height="34" width="4" x="110" y="6"></rect><rect class="hours-bar" height="32" width="4" x="115" y="8"></rect><rect class="hours-bar" height="31" width="4" x="120" y="9"></rect><rect class="hours-bar" height="32" width="4" x="125" y="8"></rect><rect class="hours-bar" height="31" width="4" x="130" y="9"></rect><rect class="hours-bar" height="34" width="4" x="135" y="6"></rect><rect class="hours-bar" height="35" width="4" x="140" y="5"></rect><rect class="hours-bar" height="29" width="4" x="145" y="11"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">124,148</td>
# <td class="num period-col player-hours">57,079,371</td>
# </tr>, <tr class="odd">
# <td>7.</td>
# <td class="game-name left">
# <a href="/app/271590">
# 						Grand Theft Auto V
# 					</a>
# </td>
# <td class="num">59,986</td>
# <td class="chart period-col" id="spark_271590" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="31" width="4" x="0" y="9"></rect><rect class="hours-bar" height="24" width="4" x="5" y="16"></rect><rect class="hours-bar" height="25" width="4" x="10" y="15"></rect><rect class="hours-bar" height="29" width="4" x="15" y="11"></rect><rect class="hours-bar" height="32" width="4" x="20" y="8"></rect><rect class="hours-bar" height="34" width="4" x="25" y="6"></rect><rect class="hours-bar" height="40" width="4" x="30" y="0"></rect><rect class="hours-bar" height="40" width="4" x="35" y="0"></rect><rect class="hours-bar" height="33" width="4" x="40" y="7"></rect><rect class="hours-bar" height="33" width="4" x="45" y="7"></rect><rect class="hours-bar" height="33" width="4" x="50" y="7"></rect><rect class="hours-bar" height="34" width="4" x="55" y="6"></rect><rect class="hours-bar" height="35" width="4" x="60" y="5"></rect><rect class="hours-bar" height="38" width="4" x="65" y="2"></rect><rect class="hours-bar" height="38" width="4" x="70" y="2"></rect><rect class="hours-bar" height="34" width="4" x="75" y="6"></rect><rect class="hours-bar" height="34" width="4" x="80" y="6"></rect><rect class="hours-bar" height="34" width="4" x="85" y="6"></rect><rect class="hours-bar" height="35" width="4" x="90" y="5"></rect><rect class="hours-bar" height="35" width="4" x="95" y="5"></rect><rect class="hours-bar" height="37" width="4" x="100" y="3"></rect><rect class="hours-bar" height="39" width="4" x="105" y="1"></rect><rect class="hours-bar" height="35" width="4" x="110" y="5"></rect><rect class="hours-bar" height="33" width="4" x="115" y="7"></rect><rect class="hours-bar" height="33" width="4" x="120" y="7"></rect><rect class="hours-bar" height="33" width="4" x="125" y="7"></rect><rect class="hours-bar" height="34" width="4" x="130" y="6"></rect><rect class="hours-bar" height="38" width="4" x="135" y="2"></rect><rect class="hours-bar" height="37" width="4" x="140" y="3"></rect><rect class="hours-bar" height="30" width="4" x="145" y="10"></rect><rect class="hours-bar ongoing" height="2" width="4" x="150" y="38"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">173,538</td>
# <td class="num period-col player-hours">72,964,915</td>
# </tr>, <tr>
# <td>8.</td>
# <td class="game-name left">
# <a href="/app/1085660">
# 						Destiny 2
# 					</a>
# </td>
# <td class="num">54,880</td>
# <td class="chart period-col" id="spark_1085660" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="40" width="4" x="0" y="0"></rect><rect class="hours-bar" height="30" width="4" x="5" y="10"></rect><rect class="hours-bar" height="34" width="4" x="10" y="6"></rect><rect class="hours-bar" height="38" width="4" x="15" y="2"></rect><rect class="hours-bar" height="32" width="4" x="20" y="8"></rect><rect class="hours-bar" height="33" width="4" x="25" y="7"></rect><rect class="hours-bar" height="37" width="4" x="30" y="3"></rect><rect class="hours-bar" height="36" width="4" x="35" y="4"></rect><rect class="hours-bar" height="30" width="4" x="40" y="10"></rect><rect class="hours-bar" height="31" width="4" x="45" y="9"></rect><rect class="hours-bar" height="31" width="4" x="50" y="9"></rect><rect class="hours-bar" height="28" width="4" x="55" y="12"></rect><rect class="hours-bar" height="28" width="4" x="60" y="12"></rect><rect class="hours-bar" height="27" width="4" x="65" y="13"></rect><rect class="hours-bar" height="28" width="4" x="70" y="12"></rect><rect class="hours-bar" height="28" width="4" x="75" y="12"></rect><rect class="hours-bar" height="30" width="4" x="80" y="10"></rect><rect class="hours-bar" height="30" width="4" x="85" y="10"></rect><rect class="hours-bar" height="28" width="4" x="90" y="12"></rect><rect class="hours-bar" height="28" width="4" x="95" y="12"></rect><rect class="hours-bar" height="29" width="4" x="100" y="11"></rect><rect class="hours-bar" height="32" width="4" x="105" y="8"></rect><rect class="hours-bar" height="28" width="4" x="110" y="12"></rect><rect class="hours-bar" height="26" width="4" x="115" y="14"></rect><rect class="hours-bar" height="27" width="4" x="120" y="13"></rect><rect class="hours-bar" height="26" width="4" x="125" y="14"></rect><rect class="hours-bar" height="28" width="4" x="130" y="12"></rect><rect class="hours-bar" height="32" width="4" x="135" y="8"></rect><rect class="hours-bar" height="32" width="4" x="140" y="8"></rect><rect class="hours-bar" height="24" width="4" x="145" y="16"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">107,591</td>
# <td class="num period-col player-hours">44,838,071</td>
# </tr>, <tr class="odd">
# <td>9.</td>
# <td class="game-name left">
# <a href="/app/39210">
# 						FINAL FANTASY XIV Online
# 					</a>
# </td>
# <td class="num">53,151</td>
# <td class="chart period-col" id="spark_39210" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="38" width="4" x="0" y="2"></rect><rect class="hours-bar" height="33" width="4" x="5" y="7"></rect><rect class="hours-bar" height="32" width="4" x="10" y="8"></rect><rect class="hours-bar" height="30" width="4" x="15" y="10"></rect><rect class="hours-bar" height="29" width="4" x="20" y="11"></rect><rect class="hours-bar" height="29" width="4" x="25" y="11"></rect><rect class="hours-bar" height="32" width="4" x="30" y="8"></rect><rect class="hours-bar" height="32" width="4" x="35" y="8"></rect><rect class="hours-bar" height="28" width="4" x="40" y="12"></rect><rect class="hours-bar" height="23" width="4" x="45" y="17"></rect><rect class="hours-bar" height="28" width="4" x="50" y="12"></rect><rect class="hours-bar" height="27" width="4" x="55" y="13"></rect><rect class="hours-bar" height="25" width="4" x="60" y="15"></rect><rect class="hours-bar" height="23" width="4" x="65" y="17"></rect><rect class="hours-bar" height="25" width="4" x="70" y="15"></rect><rect class="hours-bar" height="25" width="4" x="75" y="15"></rect><rect class="hours-bar" height="25" width="4" x="80" y="15"></rect><rect class="hours-bar" height="25" width="4" x="85" y="15"></rect><rect class="hours-bar" height="24" width="4" x="90" y="16"></rect><rect class="hours-bar" height="24" width="4" x="95" y="16"></rect><rect class="hours-bar" height="24" width="4" x="100" y="16"></rect><rect class="hours-bar" height="26" width="4" x="105" y="14"></rect><rect class="hours-bar" height="24" width="4" x="110" y="16"></rect><rect class="hours-bar" height="23" width="4" x="115" y="17"></rect><rect class="hours-bar" height="25" width="4" x="120" y="15"></rect><rect class="hours-bar" height="24" width="4" x="125" y="16"></rect><rect class="hours-bar" height="24" width="4" x="130" y="16"></rect><rect class="hours-bar" height="26" width="4" x="135" y="14"></rect><rect class="hours-bar" height="26" width="4" x="140" y="14"></rect><rect class="hours-bar" height="22" width="4" x="145" y="18"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">89,972</td>
# <td class="num period-col player-hours">35,431,458</td>
# </tr>, <tr>
# <td>10.</td>
# <td class="game-name left">
# <a href="/app/346110">
# 						ARK: Survival Evolved
# 					</a>
# </td>
# <td class="num">52,483</td>
# <td class="chart period-col" id="spark_346110" style="width: 150px; height: 40px;"><svg style="width: 150px; height: 40px;"><g><rect class="hours-bar" height="24" width="4" x="0" y="16"></rect><rect class="hours-bar" height="18" width="4" x="5" y="22"></rect><rect class="hours-bar" height="17" width="4" x="10" y="23"></rect><rect class="hours-bar" height="19" width="4" x="15" y="21"></rect><rect class="hours-bar" height="22" width="4" x="20" y="18"></rect><rect class="hours-bar" height="24" width="4" x="25" y="16"></rect><rect class="hours-bar" height="32" width="4" x="30" y="8"></rect><rect class="hours-bar" height="36" width="4" x="35" y="4"></rect><rect class="hours-bar" height="31" width="4" x="40" y="9"></rect><rect class="hours-bar" height="31" width="4" x="45" y="9"></rect><rect class="hours-bar" height="31" width="4" x="50" y="9"></rect><rect class="hours-bar" height="31" width="4" x="55" y="9"></rect><rect class="hours-bar" height="30" width="4" x="60" y="10"></rect><rect class="hours-bar" height="31" width="4" x="65" y="9"></rect><rect class="hours-bar" height="35" width="4" x="70" y="5"></rect><rect class="hours-bar" height="34" width="4" x="75" y="6"></rect><rect class="hours-bar" height="35" width="4" x="80" y="5"></rect><rect class="hours-bar" height="35" width="4" x="85" y="5"></rect><rect class="hours-bar" height="35" width="4" x="90" y="5"></rect><rect class="hours-bar" height="32" width="4" x="95" y="8"></rect><rect class="hours-bar" height="36" width="4" x="100" y="4"></rect><rect class="hours-bar" height="39" width="4" x="105" y="1"></rect><rect class="hours-bar" height="35" width="4" x="110" y="5"></rect><rect class="hours-bar" height="33" width="4" x="115" y="7"></rect><rect class="hours-bar" height="30" width="4" x="120" y="10"></rect><rect class="hours-bar" height="29" width="4" x="125" y="11"></rect><rect class="hours-bar" height="31" width="4" x="130" y="9"></rect><rect class="hours-bar" height="36" width="4" x="135" y="4"></rect><rect class="hours-bar" height="37" width="4" x="140" y="3"></rect><rect class="hours-bar" height="29" width="4" x="145" y="11"></rect><rect class="hours-bar ongoing" height="3" width="4" x="150" y="37"></rect></g></svg></td>
# <td class="num period-col peak-concurrent">96,650</td>
# <td class="num period-col player-hours">45,209,730</td>
# </tr>]

# %%
result_list = []
for tr in rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    result_list.append(row)

print(result_list)
# Out:
# [[], ['1.', '\n\n\t\t\t\t\t\tCounter-Strike: Global Offensive\n\t\t\t\t\t\n', '397,402', '', '895,365', '394,556,094'], ['2.', '\n\n\t\t\t\t\t\tDota 2\n\t\t\t\t\t\n', '344,758', '', '760,295', '346,344,640'], ['3.', '\n\n\t\t\t\t\t\tRust\n\t\t\t\t\t\n', '102,311', '', '154,747', '58,578,091'], ['4.', '\n\n\t\t\t\t\t\tApex Legends\n\t\t\t\t\t\n', '84,119', '', '238,911', '92,000,952'], ['5.', '\n\n\t\t\t\t\t\tTeam Fortress 2\n\t\t\t\t\t\n', '83,248', '', '129,305', '69,420,317'], ['6.', '\n\n\t\t\t\t\t\tNew World\n\t\t\t\t\t\n', '74,492', '', '124,148', '57,079,371'], ['7.', '\n\n\t\t\t\t\t\tGrand Theft Auto V\n\t\t\t\t\t\n', '59,986', '', '173,538', '72,964,915'], ['8.', '\n\n\t\t\t\t\t\tDestiny 2\n\t\t\t\t\t\n', '54,880', '', '107,591', '44,838,071'], ['9.', '\n\n\t\t\t\t\t\tFINAL FANTASY XIV Online\n\t\t\t\t\t\n', '53,151', '', '89,972', '35,431,458'], ['10.', '\n\n\t\t\t\t\t\tARK: Survival Evolved\n\t\t\t\t\t\n', '52,483', '', '96,650', '45,209,730']]

# %%
topgames_df = pd.DataFrame(result_list, columns=['Rank','Name', 'Current Players', 'Last 30 Days', 'Peak Players', 'Hours Played'])
topgames_df
# Out:
#     Rank                                               Name Current Players  \
# 0   None                                               None            None
# 1     1.  \n\n\t\t\t\t\t\tCounter-Strike: Global Offensi...         397,402
# 2     2.               \n\n\t\t\t\t\t\tDota 2\n\t\t\t\t\t\n         344,758
# 3     3.                 \n\n\t\t\t\t\t\tRust\n\t\t\t\t\t\n         102,311
# 4     4.         \n\n\t\t\t\t\t\tApex Legends\n\t\t\t\t\t\n          84,119
# 5     5.      \n\n\t\t\t\t\t\tTeam Fortress 2\n\t\t\t\t\t\n          83,248
# 6     6.            \n\n\t\t\t\t\t\tNew World\n\t\t\t\t\t\n          74,492
# 7     7.   \n\n\t\t\t\t\t\tGrand Theft Auto V\n\t\t\t\t\t\n          59,986
# 8     8.            \n\n\t\t\t\t\t\tDestiny 2\n\t\t\t\t\t\n          54,880
# 9     9.  \n\n\t\t\t\t\t\tFINAL FANTASY XIV Online\n\t\t...          53,151
# 10   10.  \n\n\t\t\t\t\t\tARK: Survival Evolved\n\t\t\t\...          52,483
#
#    Last 30 Days Peak Players Hours Played
# 0          None         None         None
# 1                    895,365  394,556,094
# 2                    760,295  346,344,640
# 3                    154,747   58,578,091
# 4                    238,911   92,000,952
# 5                    129,305   69,420,317
# 6                    124,148   57,079,371
# 7                    173,538   72,964,915
# 8                    107,591   44,838,071
# 9                     89,972   35,431,458
# 10                    96,650   45,209,730

# %%
topgames_df = topgames_df.replace(r'\n+|\t+',' ', regex=True) 
topgames_df
# Out:
#     Rank                                   Name Current Players Last 30 Days  \
# 0   None                                   None            None         None
# 1     1.    Counter-Strike: Global Offensive            397,402
# 2     2.                              Dota 2            344,758
# 3     3.                                Rust            102,311
# 4     4.                        Apex Legends             84,119
# 5     5.                     Team Fortress 2             83,248
# 6     6.                           New World             74,492
# 7     7.                  Grand Theft Auto V             59,986
# 8     8.                           Destiny 2             54,880
# 9     9.            FINAL FANTASY XIV Online             53,151
# 10   10.               ARK: Survival Evolved             52,483
#
#    Peak Players Hours Played
# 0          None         None
# 1       895,365  394,556,094
# 2       760,295  346,344,640
# 3       154,747   58,578,091
# 4       238,911   92,000,952
# 5       129,305   69,420,317
# 6       124,148   57,079,371
# 7       173,538   72,964,915
# 8       107,591   44,838,071
# 9        89,972   35,431,458
# 10       96,650   45,209,730

# %%
topgames_df.drop(['Rank', 'Last 30 Days'], axis=1, inplace=True)
topgames_df
# Out:
#                                      Name Current Players Peak Players  \
# 0                                    None            None         None
# 1     Counter-Strike: Global Offensive            397,402      895,365
# 2                               Dota 2            344,758      760,295
# 3                                 Rust            102,311      154,747
# 4                         Apex Legends             84,119      238,911
# 5                      Team Fortress 2             83,248      129,305
# 6                            New World             74,492      124,148
# 7                   Grand Theft Auto V             59,986      173,538
# 8                            Destiny 2             54,880      107,591
# 9             FINAL FANTASY XIV Online             53,151       89,972
# 10               ARK: Survival Evolved             52,483       96,650
#
#    Hours Played
# 0          None
# 1   394,556,094
# 2   346,344,640
# 3    58,578,091
# 4    92,000,952
# 5    69,420,317
# 6    57,079,371
# 7    72,964,915
# 8    44,838,071
# 9    35,431,458
# 10   45,209,730

# %%
top5 = topgames_df.drop([0, 6, 7,8,9,10])
top5
# Out:
#                                     Name Current Players Peak Players  \
# 1    Counter-Strike: Global Offensive            397,402      895,365
# 2                              Dota 2            344,758      760,295
# 3                                Rust            102,311      154,747
# 4                        Apex Legends             84,119      238,911
# 5                     Team Fortress 2             83,248      129,305
#
#   Hours Played
# 1  394,556,094
# 2  346,344,640
# 3   58,578,091
# 4   92,000,952
# 5   69,420,317

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.steamcharts_db
topgames = db.topgames
